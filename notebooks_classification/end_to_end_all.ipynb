# %%
'''basics'''
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))
sys.setrecursionlimit(20500)
import pickle
import models as md
import pandas as pd

import joblib
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jonas
# [nltk_data]     Nothnagel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Jonas
# [nltk_data]     Nothnagel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
'''import dict'''
with open(os.path.abspath(os.path.join('..', 'data/processed/'))+"/category_dict.pkl", 'rb') as handle:
    d = pickle.load(handle)

# %%
input_string =  input("Enter your text: ")

prediction, probability, hat, hat_2 = md.predict_text_all(input_string, 'tfidf_all', d, parent_only = False, tfidf =True)
# Out:
# Enter your text: test test test
# ______
# 117
# forests
# NO Confidence: 69.0 %
# ______
# 152
# conserve_areas
# NO Confidence: 63.0 %
# ______
# 56
# freshwaters
# NO Confidence: 80.0 %
# ______
# 49
# grasslands
# NO Confidence: 99.0 %
# ______
# 84
# marine
# NO Confidence: 67.0 %
# ______
# 38
# wetlands
# NO Confidence: 100.0 %
# ______
# 213
# human_altered_areas
# NO Confidence: 80.0 %
# ______
# 354.0
# capacity_building
# YES. Confidence: 56.99999999999999 %
# ____________________________________________
# predicting sub categories....
# awareness_raising
# NO Confidence: 83.0 %
#
# ____________________________________________
# technical_capacity_building
# NO Confidence: 56.99999999999999 %
#
# ____________________________________________
# institutional_capacity_building
# NO Confidence: 53.0 %
#
# ____________________________________________
# community_capacity_building
# NO Confidence: 60.0 %
#
# ____________________________________________
# mainstream
# ...
